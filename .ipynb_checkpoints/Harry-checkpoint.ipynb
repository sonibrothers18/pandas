# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name": ["mayur", "rohan", "alex", "rolex"],
    "marks": [56, 45, 85, 11],
    "city": ["rewari", "alwar", "jaipur", "usa"]
}

df = pd.DataFrame(dict1)
print(df)
# Out:
#     name  marks    city
# 0  mayur     56  rewari
# 1  rohan     45   alwar
# 2   alex     85  jaipur
# 3  rolex     11     usa

# %%
df.to_csv("friends.csv")
df.to_csv("friends2.csv", index = False)

# %%
df.head(2)
# Out:
#     name  marks    city
# 0  mayur     56  rewari
# 1  rohan     45   alwar

# %%
df.tail(2)
# Out:
#     name  marks    city
# 2   alex     85  jaipur
# 3  rolex     11     usa

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   49.250000
# std    30.576407
# min    11.000000
# 25%    36.500000
# 50%    50.500000
# 75%    63.250000
# max    85.000000

# %%
train = pd.read_csv("train.csv")

# %%
train
# Out:
#    Unnamed: 0.4  Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  train  \
# 0             0             0             0             0           0   1542
# 1             1             1             1             1           1   1521
# 2             2             2             2             2           2   5452
# 3             3             3             3             3           3   5155
#
#      city  speed
# 0   alwar   1000
# 1  jaipur     24
# 2  rewari     84
# 3     usa     75

# %%
train["speed"]
# Out:
# 0    1000
# 1      24
# 2      84
# 3      75
# Name: speed, dtype: int64

# %%
train["speed"][0]
# Out:
# np.int64(1000)

# %%
train["speed"][0] = 1000
# Out:
# C:\Users\soni1\AppData\Local\Temp\ipykernel_11884\1967554247.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["speed"][0] = 1000

# %%
train
# Out:
#    Unnamed: 0.4  Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  train  \
# 0             0             0             0             0           0   1542
# 1             1             1             1             1           1   1521
# 2             2             2             2             2           2   5452
# 3             3             3             3             3           3   5155
#
#      city  speed
# 0   alwar   1000
# 1  jaipur     24
# 2  rewari     84
# 3     usa     75

# %%
train.to_csv("train.csv")

# %%
train.index = ["first", "second", "third", "fourth"]

# %%
train
# Out:
#         Unnamed: 0.4  Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# first              0             0             0             0           0
# second             1             1             1             1           1
# third              2             2             2             2           2
# fourth             3             3             3             3           3
#
#         train    city  speed
# first    1542   alwar   1000
# second   1521  jaipur     24
# third    5452  rewari     84
# fourth   5155     usa     75

# %%
ser = pd.Series(np.random.rand(34))
ser
# Out:
# 0     0.325059
# 1     0.578105
# 2     0.489154
# 3     0.446929
# 4     0.044622
# 5     0.388546
# 6     0.506793
# 7     0.255502
# 8     0.403980
# 9     0.557991
# 10    0.169134
# 11    0.667582
# 12    0.130013
# 13    0.405803
# 14    0.334270
# 15    0.554631
# 16    0.013931
# 17    0.053919
# 18    0.228905
# 19    0.135417
# 20    0.044493
# 21    0.202396
# 22    0.090920
# 23    0.844687
# 24    0.650281
# 25    0.222341
# 26    0.844250
# 27    0.587437
# 28    0.113661
# 29    0.296147
# 30    0.243578
# 31    0.134261
# 32    0.825599
# 33    0.820263
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(334, 5), index=np.arange(334))
newdf
# Out:
#             0         1         2         3         4
# 0    0.348540  0.831890  0.312283  0.047909  0.628232
# 1    0.627963  0.571025  0.848422  0.055849  0.265940
# 2    0.310941  0.320409  0.266246  0.901605  0.015703
# 3    0.546465  0.178455  0.569779  0.065121  0.449071
# 4    0.662492  0.169027  0.897282  0.707950  0.517621
# ..        ...       ...       ...       ...       ...
# 329  0.713685  0.883832  0.372529  0.865248  0.406784
# 330  0.983926  0.866988  0.245292  0.735044  0.618316
# 331  0.952541  0.923335  0.909267  0.835762  0.371850
# 332  0.294238  0.943530  0.197124  0.846041  0.969349
# 333  0.990962  0.943944  0.833072  0.690028  0.299585
#
# [334 rows x 5 columns]

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0
#
# [334 rows x 5 columns]

# %%
newdf.loc[[1,2], ["C", "A", "D"]]
# Out:
#           C         A         D
# 1  0.848422  0.627963  0.055849
# 2  0.266246  0.310941  0.901605

# %%
newdf.loc[:, ["C", "A", "D"]]
# Out:
#             C            A         D
# 0    0.312283  9999.000000  0.047909
# 1    0.848422     0.627963  0.055849
# 2    0.266246     0.310941  0.901605
# 3    0.569779     0.546465  0.065121
# 4    0.897282     0.662492  0.707950
# ..        ...          ...       ...
# 329  0.372529     0.713685  0.865248
# 330  0.245292     0.983926  0.735044
# 331  0.909267     0.952541  0.835762
# 332  0.197124     0.294238  0.846041
# 333  0.833072     0.990962  0.690028
#
# [334 rows x 3 columns]

# %%
newdf.loc[(newdf["A"]<0.3)]
# Out:
#             A         B         C         D         E
# 5    0.088132  0.096621  0.871159  0.363937  0.023691
# 12   0.279413  0.508509  0.070062  0.085079  0.708992
# 17   0.155427  0.893966  0.406329  0.888073  0.478673
# 22   0.123658  0.029074  0.688831  0.048177  0.338505
# 23   0.011245  0.518219  0.610009  0.908479  0.545066
# ..        ...       ...       ...       ...       ...
# 306  0.276851  0.242442  0.020904  0.038876  0.964379
# 307  0.198810  0.898046  0.676473  0.615835  0.189637
# 323  0.090019  0.013005  0.840628  0.247230  0.840443
# 326  0.208901  0.195307  0.780311  0.081455  0.597593
# 332  0.294238  0.943530  0.197124  0.846041  0.969349
#
# [93 rows x 5 columns]

# %%
newdf.loc[(newdf["A"]<0.3) & (newdf["C"]>0.1)]
# Out:
#             A         B         C         D         E
# 5    0.088132  0.096621  0.871159  0.363937  0.023691
# 17   0.155427  0.893966  0.406329  0.888073  0.478673
# 22   0.123658  0.029074  0.688831  0.048177  0.338505
# 23   0.011245  0.518219  0.610009  0.908479  0.545066
# 24   0.270449  0.514321  0.266348  0.801365  0.324582
# ..        ...       ...       ...       ...       ...
# 303  0.143550  0.854714  0.940806  0.239836  0.165618
# 307  0.198810  0.898046  0.676473  0.615835  0.189637
# 323  0.090019  0.013005  0.840628  0.247230  0.840443
# 326  0.208901  0.195307  0.780311  0.081455  0.597593
# 332  0.294238  0.943530  0.197124  0.846041  0.969349
#
# [81 rows x 5 columns]

# %%
newdf.iloc[0,4] # index counting
# Out:
# np.float64(0.6282319372559246)

# %%
newdf.iloc[[0,1], [1,2]]
# Out:
#           B         C
# 0  0.831890  0.312283
# 1  0.571025  0.848422

# %%
newdf.drop(["A", "C"], axis=1)
# Out:
#             B         D         E
# 0    0.831890  0.047909  0.628232
# 1    0.571025  0.055849  0.265940
# 2    0.320409  0.901605  0.015703
# 3    0.178455  0.065121  0.449071
# 4    0.169027  0.707950  0.517621
# ..        ...       ...       ...
# 329  0.883832  0.865248  0.406784
# 330  0.866988  0.735044  0.618316
# 331  0.923335  0.835762  0.371850
# 332  0.943530  0.846041  0.969349
# 333  0.943944  0.690028  0.299585
#
# [334 rows x 3 columns]

# %%
newdf.drop([1, 5], axis=0, inplace=True)

# %%
newdf.head(5)
# Out:
#              A         B         C         D         E
# 0  9999.000000  0.831890  0.312283  0.047909  0.628232
# 2     0.310941  0.320409  0.266246  0.901605  0.015703
# 3     0.546465  0.178455  0.569779  0.065121  0.449071
# 4     0.662492  0.169027  0.897282  0.707950  0.517621
# 6     0.638065  0.729785  0.534786  0.155684  0.957412

# %%
newdf.reset_index(drop=True, inplace=True)

# %%
newdf.head(5)
# Out:
#              A         B         C         D         E
# 0  9999.000000  0.831890  0.312283  0.047909  0.628232
# 1     0.310941  0.320409  0.266246  0.901605  0.015703
# 2     0.546465  0.178455  0.569779  0.065121  0.449071
# 3     0.662492  0.169027  0.897282  0.707950  0.517621
# 4     0.638065  0.729785  0.534786  0.155684  0.957412

# %%
newdf["B"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 327    False
# 328    False
# 329    False
# 330    False
# 331    False
# Name: B, Length: 332, dtype: bool

# %%
newdf["B"] = None
newdf
# Out:
#                A     B         C         D         E
# 0    9999.000000  None  0.312283  0.047909  0.628232
# 1       0.310941  None  0.266246  0.901605  0.015703
# 2       0.546465  None  0.569779  0.065121  0.449071
# 3       0.662492  None  0.897282  0.707950  0.517621
# 4       0.638065  None  0.534786  0.155684  0.957412
# ..           ...   ...       ...       ...       ...
# 327     0.713685  None  0.372529  0.865248  0.406784
# 328     0.983926  None  0.245292  0.735044  0.618316
# 329     0.952541  None  0.909267  0.835762  0.371850
# 330     0.294238  None  0.197124  0.846041  0.969349
# 331     0.990962  None  0.833072  0.690028  0.299585
#
# [332 rows x 5 columns]

# %%
newdf["B"].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 327    True
# 328    True
# 329    True
# 330    True
# 331    True
# Name: B, Length: 332, dtype: bool

# %%
newdf.loc[:, ["B"]] = 999
newdf.head(5)
# Out:
#              A    B         C         D         E
# 0  9999.000000  999  0.312283  0.047909  0.628232
# 1     0.310941  999  0.266246  0.901605  0.015703
# 2     0.546465  999  0.569779  0.065121  0.449071
# 3     0.662492  999  0.897282  0.707950  0.517621
# 4     0.638065  999  0.534786  0.155684  0.957412

# %%
df = pd.DataFrame({
    "name": ["mayur", "alex", "rat"],
    "toy": [np.nan, np.nan, np.nan],
    "born": [pd.NaT, pd.Timestamp("1940-04-25"), pd.NaT]
})

# %%
df.head()
# Out:
#     name  toy       born
# 0  mayur  NaN        NaT
# 1   alex  NaN 1940-04-25
# 2    rat  NaN        NaT

# %%
df.dropna(how="all", axis=1)
# Out:
#     name       born
# 0  mayur        NaT
# 1   alex 1940-04-25
# 2    rat        NaT

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [name, toy, born]
# Index: []

# %%
df
# Out:
#     name  toy       born
# 0  mayur  NaN        NaT
# 1   alex  NaN 1940-04-25
# 2    rat  NaN        NaT

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   toy     0 non-null      float64
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 204.0+ bytes

# %%
df["born"].value_counts()
# Out:
# born
# 1940-04-25    1
# Name: count, dtype: int64

# %%
df["born"].value_counts(dropna=False)
# Out:
# born
# NaT           2
# 1940-04-25    1
# Name: count, dtype: int64

# %%
df.notnull()
# Out:
#    name    toy   born
# 0  True  False  False
# 1  True  False   True
# 2  True  False  False

# %%
df.isnull()
# Out:
#     name   toy   born
# 0  False  True   True
# 1  False  True  False
# 2  False  True   True

# %%
data = pd.read_excel('data.xlsx')

# %%
data
# Out:
#    train  speed
# 0   1524      15
# 1   4112      54
# 2   4854      10

# %%
data2 = pd.read_excel('data.xlsx', sheet_name="Sheet2")

# %%
data2
# Out:
#    train2  speed2
# 0    7842      84
# 1    9854      10
# 2    4529     100

# %%
data.iloc[0,0] = 999999
data
# Out:
#     train  speed
# 0  999999      15
# 1    4112      54
# 2    4854      10

# %%
data.to_excel("data.xlsx", sheet_name="Sheet2")
